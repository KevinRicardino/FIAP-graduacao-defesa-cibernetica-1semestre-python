# %%
vetor1 = [1, 3, 5, 7, 9]
vetor2 = [2, 4, 6, 8, 10]

novo_vetor = [(vetor1[i] ** 2 + vetor2[i] ** 3) for i in range(len(vetor1))]
string_resultante = ''.join(map(str, novo_vetor))
substring = string_resultante[2:8]
substring_invertida = substring[::-1]

print("Saída:", substring)
# Out:
# Saída: 324156
