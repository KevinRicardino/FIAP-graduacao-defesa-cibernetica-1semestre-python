# %%
# Lista de ferramentas de cibersegurança
ferramentas_cyber = ["Wireshark", "Metasploit", "Nmap", "Burp Suite", "Snort", "OpenVAS", "Cuckoo Sandbox"]

letras_maiusculas = ''.join([ferramenta.upper() for ferramenta in ferramentas_cyber])

comprimento_string = len(letras_maisculas)

substring = letras_maisculas[5:15]

substring_invertida = substring[::-1]

print("Saída:", substring_invertida)
# Out:
# Saída: PSATEMKRAH
